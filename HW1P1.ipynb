# %%
import torch 
from torchvision import transforms 
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Problem 1**

# %%
img = Image.open("/content/drive/MyDrive/Colab Notebooks/Howework1/Blue Balloon.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=205x245 at 0x7FA91B454A10>

# %%
transform = transforms.ToTensor()
imgTensor = transform(img)
# imgTensor
print("Shape of Image Tensor: \n", imgTensor.shape)
# Out:
# Shape of Image Tensor:
#  torch.Size([3, 245, 205])

# %%
R_mean, G_mean ,B_mean = torch.mean(imgTensor, dim = [1,2])
print("Mean across Red channel:", R_mean) 
print("Mean across Green channel:", G_mean) 
print("Mean across Blue channel:", B_mean)
# Out:
# Mean across Red channel: tensor(0.3714)
# Mean across Green channel: tensor(0.5997)
# Mean across Blue channel: tensor(0.7749)
