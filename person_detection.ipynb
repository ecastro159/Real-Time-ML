# %% [markdown]
# <a href="https://colab.research.google.com/github/ecastro159/Real-Time-ML/blob/main/person_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This code is modified from the visual wake word / person detection MLPerf Tiny Benchmark:
# https://github.com/mlcommons/tiny/tree/master/benchmark/training/visual_wake_words

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/IOT/Project2
# Out:
# /content/drive/MyDrive/Colab Notebooks/IOT/Project2

# %%
import numpy as np

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Activation, Flatten, BatchNormalization
from tensorflow.keras.layers import Conv2D, DepthwiseConv2D, AveragePooling2D, MaxPooling2D
from tensorflow.keras.regularizers import l2

import os
from absl import app

assert tf.__version__.startswith('2')

# %%
IMAGE_SIZE = 96
BATCH_SIZE = 32


batch_size = 50
validation_split = 0.1

epochs = 20,10,20
lrates = .001, .0005, .00025

color_mode = 'grayscale'
if color_mode == 'grayscale':
  n_color_chans = 1
elif color_mode == 'rgb':
  n_color_chans = 3
else:
  raise ValueError("color_mode should be either 'rgb' or 'grayscale'")

# BASE_DIR = os.path.join(os.getcwd(), 'vw_coco2014_96')
BASE_DIR = '/content/drive/MyDrive/Colab Notebooks/IOT/Project2/SingleLetterDataset'

# %% [markdown]
# Build the model

# %%
### vww_model.py
'''
MobilnetV1 from Silican Labs github page:
https://github.com/SiliconLabs/platform_ml_models/blob/master/eembc/Person_detection/mobilenet_v1_eembc.py
'''


#define model
def mobilenet_v1():
    # Mobilenet parameters
    input_shape = [96,96,1] # resized to 96x96 per EEMBC requirement # was [96,96,3]
    num_classes = 2 # person and non-person
    num_filters = 8 # normally 32, but running with alpha=.25 per EEMBC requirement

    inputs = Input(shape=input_shape)
    x = inputs # Keras model uses ZeroPadding2D()

    # 1st layer, pure conv
    # Keras 2.2 model has padding='valid' and disables bias
    x = Conv2D(num_filters,
                  kernel_size=3,
                  strides=2,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x) # Keras uses ReLU6 instead of pure ReLU

    # 2nd layer, depthwise separable conv
    # Filter size is always doubled before the pointwise conv
    # Keras uses ZeroPadding2D() and padding='valid'
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    num_filters = 2*num_filters
    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 3rd layer, depthwise separable conv
    x = DepthwiseConv2D(kernel_size=3,
                  strides=2,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    num_filters = 2*num_filters
    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 4th layer, depthwise separable conv
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 5th layer, depthwise separable conv
    x = DepthwiseConv2D(kernel_size=3,
                  strides=2,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    num_filters = 2*num_filters
    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 6th layer, depthwise separable conv
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 7th layer, depthwise separable conv
    x = DepthwiseConv2D(kernel_size=3,
                  strides=2,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    num_filters = 2*num_filters
    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 8th-12th layers, identical depthwise separable convs
    # 8th
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 9th
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 10th
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 11th
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 12th
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 13th layer, depthwise separable conv
    x = DepthwiseConv2D(kernel_size=3,
                  strides=2,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    num_filters = 2*num_filters
    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # 14th layer, depthwise separable conv
    x = DepthwiseConv2D(kernel_size=3,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(num_filters,
                  kernel_size=1,
                  strides=1,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Average pooling, max polling may be used also
    # Keras employs GlobalAveragePooling2D 
    x = AveragePooling2D(pool_size=x.shape[1:3])(x)
    #x = MaxPooling2D(pool_size=x.shape[1:3])(x)

    # Keras inserts Dropout() and a pointwise Conv2D() here
    # We are staying with the paper base structure

    # Flatten, FC layer and classify
    x = Flatten()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
### train_vww.py
"""Training for the visual wakewords person detection model.

The visual wakewords person detection model is a core model for the TinyMLPerf
benchmark suite. This script provides source for how the reference model was
created and trained, and can be used as a starting point for open submissions
using re-training.
"""

model = mobilenet_v1()

# model.summary()

datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=.1,
    horizontal_flip=True,
    validation_split=validation_split,
    rescale=1. / 255)





train_generator = datagen.flow_from_directory(
    BASE_DIR,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    subset='training',
    color_mode='grayscale') # was 'rgb'



    
val_generator = datagen.flow_from_directory(
    BASE_DIR,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    subset='validation',
    color_mode='grayscale') # was 'rgb'
print(train_generator.class_indices)


def train_epochs(model, train_generator, val_generator, epoch_count,
                 learning_rate, steps_per_epoch=None):
  model.compile(
      optimizer=tf.keras.optimizers.Adam(learning_rate),
      loss='categorical_crossentropy',
      metrics=['accuracy'])
  if steps_per_epoch is None:
    steps_per_epoch = len(train_generator)
  history_fine = model.fit(
      train_generator,
      steps_per_epoch=steps_per_epoch,
      epochs=epoch_count,
      validation_data=val_generator,
      validation_steps=len(val_generator),
      batch_size=BATCH_SIZE)
  return model

model = train_epochs(model, train_generator, val_generator, epochs[0], lrates[0])# steps_per_epoch=10)
model = train_epochs(model, train_generator, val_generator, epochs[1], lrates[1])
model = train_epochs(model, train_generator, val_generator, epochs[2], lrates[2])

model.save('vww_96_tmp_res.h5')
# Out:
# Found 21157 images belonging to 2 classes.
# Found 2350 images belonging to 2 classes.
# {'K': 0, 'OtherLetters': 1}
# Epoch 1/20
# 662/662 [==============================] - 576s 857ms/step - loss: 0.6267 - accuracy: 0.8778 - val_loss: 0.8532 - val_accuracy: 0.6868
# Epoch 2/20
# 662/662 [==============================] - 221s 334ms/step - loss: 0.4438 - accuracy: 0.9265 - val_loss: 0.4178 - val_accuracy: 0.9302
# Epoch 3/20
# 662/662 [==============================] - 221s 333ms/step - loss: 0.3555 - accuracy: 0.9508 - val_loss: 0.2677 - val_accuracy: 0.9881
# Epoch 4/20
# 662/662 [==============================] - 218s 330ms/step - loss: 0.2980 - accuracy: 0.9654 - val_loss: 0.2317 - val_accuracy: 0.9915
# Epoch 5/20
# 662/662 [==============================] - 219s 331ms/step - loss: 0.2552 - accuracy: 0.9743 - val_loss: 0.2049 - val_accuracy: 0.9902
# Epoch 6/20
# 662/662 [==============================] - 219s 331ms/step - loss: 0.2236 - accuracy: 0.9797 - val_loss: 0.1836 - val_accuracy: 0.9945
# Epoch 7/20
# 662/662 [==============================] - 220s 332ms/step - loss: 0.1949 - accuracy: 0.9846 - val_loss: 0.1853 - val_accuracy: 0.9855
# Epoch 8/20
# 662/662 [==============================] - 219s 331ms/step - loss: 0.1732 - accuracy: 0.9864 - val_loss: 0.2030 - val_accuracy: 0.9796
# Epoch 9/20
# 662/662 [==============================] - 218s 329ms/step - loss: 0.1559 - accuracy: 0.9880 - val_loss: 0.1532 - val_accuracy: 0.9881
# Epoch 10/20
# 662/662 [==============================] - 220s 332ms/step - loss: 0.1408 - accuracy: 0.9896 - val_loss: 0.1137 - val_accuracy: 0.9966
# Epoch 11/20
# 662/662 [==============================] - 220s 332ms/step - loss: 0.1286 - accuracy: 0.9897 - val_loss: 0.4428 - val_accuracy: 0.9447
# Epoch 12/20
# 662/662 [==============================] - 224s 338ms/step - loss: 0.1203 - accuracy: 0.9894 - val_loss: 0.1677 - val_accuracy: 0.9791
# Epoch 13/20
# 662/662 [==============================] - 222s 335ms/step - loss: 0.1043 - accuracy: 0.9922 - val_loss: 0.1277 - val_accuracy: 0.9877
# Epoch 14/20
# 662/662 [==============================] - 222s 335ms/step - loss: 0.0987 - accuracy: 0.9924 - val_loss: 0.1319 - val_accuracy: 0.9860
# Epoch 15/20
# 662/662 [==============================] - 222s 335ms/step - loss: 0.0906 - accuracy: 0.9933 - val_loss: 0.4856 - val_accuracy: 0.9357
# Epoch 16/20
# 662/662 [==============================] - 220s 332ms/step - loss: 0.0820 - accuracy: 0.9945 - val_loss: 0.0670 - val_accuracy: 0.9987
# Epoch 17/20
# 662/662 [==============================] - 220s 332ms/step - loss: 0.0789 - accuracy: 0.9940 - val_loss: 0.0694 - val_accuracy: 0.9949
# Epoch 18/20
# 662/662 [==============================] - 223s 336ms/step - loss: 0.0782 - accuracy: 0.9934 - val_loss: 0.0771 - val_accuracy: 0.9906
# Epoch 19/20
# 662/662 [==============================] - 222s 336ms/step - loss: 0.0695 - accuracy: 0.9944 - val_loss: 0.0649 - val_accuracy: 0.9953
# Epoch 20/20
# 662/662 [==============================] - 223s 337ms/step - loss: 0.0666 - accuracy: 0.9946 - val_loss: 0.0915 - val_accuracy: 0.9855
# Epoch 1/10
# 662/662 [==============================] - 227s 337ms/step - loss: 0.0542 - accuracy: 0.9974 - val_loss: 0.1191 - val_accuracy: 0.9902
# Epoch 2/10
# 662/662 [==============================] - 223s 337ms/step - loss: 0.0526 - accuracy: 0.9967 - val_loss: 0.1034 - val_accuracy: 0.9868
# Epoch 3/10
# 662/662 [==============================] - 224s 338ms/step - loss: 0.0490 - accuracy: 0.9971 - val_loss: 0.0854 - val_accuracy: 0.9902
# Epoch 4/10
# 662/662 [==============================] - 225s 340ms/step - loss: 0.0427 - accuracy: 0.9984 - val_loss: 0.1708 - val_accuracy: 0.9796
# Epoch 5/10
# 662/662 [==============================] - 225s 340ms/step - loss: 0.0432 - accuracy: 0.9977 - val_loss: 0.0831 - val_accuracy: 0.9911
# Epoch 6/10
# 662/662 [==============================] - 226s 341ms/step - loss: 0.0429 - accuracy: 0.9974 - val_loss: 0.1220 - val_accuracy: 0.9877
# Epoch 7/10
# 662/662 [==============================] - 225s 340ms/step - loss: 0.0396 - accuracy: 0.9981 - val_loss: 0.6342 - val_accuracy: 0.8736
# Epoch 8/10
# 662/662 [==============================] - 225s 340ms/step - loss: 0.0415 - accuracy: 0.9974 - val_loss: 0.0706 - val_accuracy: 0.9889
# Epoch 9/10
# 662/662 [==============================] - 225s 339ms/step - loss: 0.0373 - accuracy: 0.9981 - val_loss: 0.0432 - val_accuracy: 0.9945
# Epoch 10/10
# 662/662 [==============================] - 224s 339ms/step - loss: 0.0371 - accuracy: 0.9976 - val_loss: 0.0611 - val_accuracy: 0.9919
# Epoch 1/20
# 662/662 [==============================] - 228s 339ms/step - loss: 0.0331 - accuracy: 0.9987 - val_loss: 0.1595 - val_accuracy: 0.9800
# Epoch 2/20
# 662/662 [==============================] - 226s 342ms/step - loss: 0.0336 - accuracy: 0.9983 - val_loss: 0.0574 - val_accuracy: 0.9919
# Epoch 3/20
# 662/662 [==============================] - 223s 336ms/step - loss: 0.0298 - accuracy: 0.9994 - val_loss: 0.1291 - val_accuracy: 0.9851
# Epoch 4/20
# 662/662 [==============================] - 224s 338ms/step - loss: 0.0301 - accuracy: 0.9991 - val_loss: 0.0884 - val_accuracy: 0.9881
# Epoch 5/20
# 662/662 [==============================] - 223s 336ms/step - loss: 0.0285 - accuracy: 0.9992 - val_loss: 0.1276 - val_accuracy: 0.9830
# Epoch 6/20
# 662/662 [==============================] - 223s 337ms/step - loss: 0.0286 - accuracy: 0.9990 - val_loss: 0.0499 - val_accuracy: 0.9940
# Epoch 7/20
# 662/662 [==============================] - 224s 338ms/step - loss: 0.0279 - accuracy: 0.9990 - val_loss: 0.0826 - val_accuracy: 0.9877
# Epoch 8/20
# 662/662 [==============================] - 223s 336ms/step - loss: 0.0276 - accuracy: 0.9993 - val_loss: 0.0519 - val_accuracy: 0.9923
# Epoch 9/20
# 662/662 [==============================] - 223s 336ms/step - loss: 0.0263 - accuracy: 0.9993 - val_loss: 0.0406 - val_accuracy: 0.9936
# Epoch 10/20
# 662/662 [==============================] - 222s 335ms/step - loss: 0.0274 - accuracy: 0.9990 - val_loss: 0.0361 - val_accuracy: 0.9953
# Epoch 11/20
# 662/662 [==============================] - 223s 337ms/step - loss: 0.0268 - accuracy: 0.9990 - val_loss: 0.0398 - val_accuracy: 0.9957
# Epoch 12/20
# 662/662 [==============================] - 223s 337ms/step - loss: 0.0252 - accuracy: 0.9993 - val_loss: 0.0664 - val_accuracy: 0.9889
# Epoch 13/20
# 662/662 [==============================] - 224s 338ms/step - loss: 0.0256 - accuracy: 0.9989 - val_loss: 0.0761 - val_accuracy: 0.9902
# Epoch 14/20
# 662/662 [==============================] - 224s 339ms/step - loss: 0.0234 - accuracy: 0.9994 - val_loss: 0.0999 - val_accuracy: 0.9791
# Epoch 15/20
# 662/662 [==============================] - 223s 337ms/step - loss: 0.0250 - accuracy: 0.9988 - val_loss: 0.0837 - val_accuracy: 0.9872
# Epoch 16/20
# 662/662 [==============================] - 223s 337ms/step - loss: 0.0239 - accuracy: 0.9989 - val_loss: 0.0517 - val_accuracy: 0.9911
# Epoch 17/20
# 662/662 [==============================] - 225s 339ms/step - loss: 0.0236 - accuracy: 0.9994 - val_loss: 0.0569 - val_accuracy: 0.9911
# Epoch 18/20
# 662/662 [==============================] - 223s 336ms/step - loss: 0.0223 - accuracy: 0.9995 - val_loss: 0.0700 - val_accuracy: 0.9902
# Epoch 19/20
# 662/662 [==============================] - 222s 336ms/step - loss: 0.0237 - accuracy: 0.9989 - val_loss: 0.0484 - val_accuracy: 0.9919
# Epoch 20/20
# 662/662 [==============================] - 222s 335ms/step - loss: 0.0214 - accuracy: 0.9996 - val_loss: 0.0500 - val_accuracy: 0.9919

# %%
val_loss, val_acc = model.evaluate(val_generator, verbose=2)
# Out:
# 74/74 - 12s - loss: 0.0478 - accuracy: 0.9923 - 12s/epoch - 166ms/step

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d_28 (Conv2D)          (None, 48, 48, 8)         80
#
#  batch_normalization_54 (Bat  (None, 48, 48, 8)        32
#  chNormalization)
#
#  activation_54 (Activation)  (None, 48, 48, 8)         0
#
#  depthwise_conv2d_26 (Depthw  (None, 48, 48, 8)        80
#  iseConv2D)
#
#  batch_normalization_55 (Bat  (None, 48, 48, 8)        32
#  chNormalization)
#
#  activation_55 (Activation)  (None, 48, 48, 8)         0
#
#  conv2d_29 (Conv2D)          (None, 48, 48, 16)        144
#
#  batch_normalization_56 (Bat  (None, 48, 48, 16)       64
#  chNormalization)
#
#  activation_56 (Activation)  (None, 48, 48, 16)        0
#
#  depthwise_conv2d_27 (Depthw  (None, 24, 24, 16)       160
#  iseConv2D)
#
#  batch_normalization_57 (Bat  (None, 24, 24, 16)       64
#  chNormalization)
#
#  activation_57 (Activation)  (None, 24, 24, 16)        0
#
#  conv2d_30 (Conv2D)          (None, 24, 24, 32)        544
#
#  batch_normalization_58 (Bat  (None, 24, 24, 32)       128
#  chNormalization)
#
#  activation_58 (Activation)  (None, 24, 24, 32)        0
#
#  depthwise_conv2d_28 (Depthw  (None, 24, 24, 32)       320
#  iseConv2D)
#
#  batch_normalization_59 (Bat  (None, 24, 24, 32)       128
#  chNormalization)
#
#  activation_59 (Activation)  (None, 24, 24, 32)        0
#
#  conv2d_31 (Conv2D)          (None, 24, 24, 32)        1056
#
#  batch_normalization_60 (Bat  (None, 24, 24, 32)       128
#  chNormalization)
#
#  activation_60 (Activation)  (None, 24, 24, 32)        0
#
#  depthwise_conv2d_29 (Depthw  (None, 12, 12, 32)       320
#  iseConv2D)
#
#  batch_normalization_61 (Bat  (None, 12, 12, 32)       128
#  chNormalization)
#
#  activation_61 (Activation)  (None, 12, 12, 32)        0
#
#  conv2d_32 (Conv2D)          (None, 12, 12, 64)        2112
#
#  batch_normalization_62 (Bat  (None, 12, 12, 64)       256
#  chNormalization)
#
#  activation_62 (Activation)  (None, 12, 12, 64)        0
#
#  depthwise_conv2d_30 (Depthw  (None, 12, 12, 64)       640
#  iseConv2D)
#
#  batch_normalization_63 (Bat  (None, 12, 12, 64)       256
#  chNormalization)
#
#  activation_63 (Activation)  (None, 12, 12, 64)        0
#
#  conv2d_33 (Conv2D)          (None, 12, 12, 64)        4160
#
#  batch_normalization_64 (Bat  (None, 12, 12, 64)       256
#  chNormalization)
#
#  activation_64 (Activation)  (None, 12, 12, 64)        0
#
#  depthwise_conv2d_31 (Depthw  (None, 6, 6, 64)         640
#  iseConv2D)
#
#  batch_normalization_65 (Bat  (None, 6, 6, 64)         256
#  chNormalization)
#
#  activation_65 (Activation)  (None, 6, 6, 64)          0
#
#  conv2d_34 (Conv2D)          (None, 6, 6, 128)         8320
#
#  batch_normalization_66 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_66 (Activation)  (None, 6, 6, 128)         0
#
#  depthwise_conv2d_32 (Depthw  (None, 6, 6, 128)        1280
#  iseConv2D)
#
#  batch_normalization_67 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_67 (Activation)  (None, 6, 6, 128)         0
#
#  conv2d_35 (Conv2D)          (None, 6, 6, 128)         16512
#
#  batch_normalization_68 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_68 (Activation)  (None, 6, 6, 128)         0
#
#  depthwise_conv2d_33 (Depthw  (None, 6, 6, 128)        1280
#  iseConv2D)
#
#  batch_normalization_69 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_69 (Activation)  (None, 6, 6, 128)         0
#
#  conv2d_36 (Conv2D)          (None, 6, 6, 128)         16512
#
#  batch_normalization_70 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_70 (Activation)  (None, 6, 6, 128)         0
#
#  depthwise_conv2d_34 (Depthw  (None, 6, 6, 128)        1280
#  iseConv2D)
#
#  batch_normalization_71 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_71 (Activation)  (None, 6, 6, 128)         0
#
#  conv2d_37 (Conv2D)          (None, 6, 6, 128)         16512
#
#  batch_normalization_72 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_72 (Activation)  (None, 6, 6, 128)         0
#
#  depthwise_conv2d_35 (Depthw  (None, 6, 6, 128)        1280
#  iseConv2D)
#
#  batch_normalization_73 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_73 (Activation)  (None, 6, 6, 128)         0
#
#  conv2d_38 (Conv2D)          (None, 6, 6, 128)         16512
#
#  batch_normalization_74 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_74 (Activation)  (None, 6, 6, 128)         0
#
#  depthwise_conv2d_36 (Depthw  (None, 6, 6, 128)        1280
#  iseConv2D)
#
#  batch_normalization_75 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_75 (Activation)  (None, 6, 6, 128)         0
#
#  conv2d_39 (Conv2D)          (None, 6, 6, 128)         16512
#
#  batch_normalization_76 (Bat  (None, 6, 6, 128)        512
#  chNormalization)
#
#  activation_76 (Activation)  (None, 6, 6, 128)         0
#
#  depthwise_conv2d_37 (Depthw  (None, 3, 3, 128)        1280
#  iseConv2D)
#
#  batch_normalization_77 (Bat  (None, 3, 3, 128)        512
#  chNormalization)
#
#  activation_77 (Activation)  (None, 3, 3, 128)         0
#
#  conv2d_40 (Conv2D)          (None, 3, 3, 256)         33024
#
#  batch_normalization_78 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  activation_78 (Activation)  (None, 3, 3, 256)         0
#
#  depthwise_conv2d_38 (Depthw  (None, 3, 3, 256)        2560
#  iseConv2D)
#
#  batch_normalization_79 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  activation_79 (Activation)  (None, 3, 3, 256)         0
#
#  conv2d_41 (Conv2D)          (None, 3, 3, 256)         65792
#
#  batch_normalization_80 (Bat  (None, 3, 3, 256)        1024
#  chNormalization)
#
#  activation_80 (Activation)  (None, 3, 3, 256)         0
#
#  average_pooling2d_2 (Averag  (None, 1, 1, 256)        0
#  ePooling2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 221,650
# Trainable params: 216,178
# Non-trainable params: 5,472
# _________________________________________________________________

# %%
### From convert_vww.py

# model = tf.keras.models.load_model(argv[1])
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# with tf.io.gfile.GFile('vww_96_float.tflite', 'wb') as float_file:
#   float_file.write(tflite_model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]
def representative_dataset_gen():
  dataset_dir = os.path.join(BASE_DIR, "K")
  for idx, image_file in enumerate(os.listdir(dataset_dir)):
    # 10 representative images should be enough for calibration.
    if idx > 10:
        return
    full_path = os.path.join(dataset_dir, image_file)
    if os.path.isfile(full_path):
      img = tf.keras.preprocessing.image.load_img(
          full_path, color_mode=color_mode).resize((96, 96))
      arr = tf.keras.preprocessing.image.img_to_array(img)
      # Scale input to [0, 1.0] like in training.
      yield [arr.reshape(1, 96, 96, n_color_chans) / 255.] 

# Convert model to full-int8 and save as quantized tflite flatbuffer.
converter.representative_dataset = representative_dataset_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
quantized_tflite_model = converter.convert()
with tf.io.gfile.GFile('vww_96_int8.tflite', 'wb') as quantized_file:
    quantized_file.write(quantized_tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp319ndjsu/assets
# INFO:tensorflow:Assets written to: /tmp/tmp319ndjsu/assets
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# INFO:tensorflow:Assets written to: /tmp/tmph9_9z9vl/assets
# INFO:tensorflow:Assets written to: /tmp/tmph9_9z9vl/assets
# /usr/local/lib/python3.7/dist-packages/tensorflow/lite/python/convert.py:746: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %%
# rebuild the val-set generator with batch-size = 1
val_generator = datagen.flow_from_directory(
    BASE_DIR,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=1,
    subset='validation',
    color_mode='grayscale')
# Out:
# Found 2350 images belonging to 2 classes.

# %%
b = val_generator.next()

# %%
b[1].shape
# Out:
# (1, 2)

# %%
plt.imshow(-b[0][0,:,:,0], cmap='Greys')
print(b[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-674438b5b355> in <module>()
# ----> 1 plt.imshow(-b[0][0,:,:,0], cmap='Greys')
#       2 print(b[1])
#
# NameError: name 'plt' is not defined

# %%
def evaluate_model(interpreter, datagen):
  input_index = interpreter.get_input_details()[0]["index"]
  output_index = interpreter.get_output_details()[0]["index"]

  labels = labels.squeeze()
  # Run predictions on every image in the "test" dataset.
  prediction_digits = []
  for i, test_image in enumerate(inputs):
    if i % 1000 == 0:
      print('Evaluated on {n} results so far.'.format(n=i))
    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_image = np.expand_dims(test_image, axis=0).astype(np.float32)
    interpreter.set_tensor(input_index, test_image)

    # Run inference.
    interpreter.invoke()

    # Post-processing: remove batch dimension and find the digit with highest
    # probability.
    output = interpreter.tensor(output_index)
    digit = np.argmax(output()[0])
    prediction_digits.append(digit)

  print('\n')
  # Compare prediction results with ground truth labels to calculate accuracy.
  prediction_digits = np.array(prediction_digits)
  accuracy = (prediction_digits == labels).mean()
  return accuracy, prediction_digits
